# %% [markdown]
# # 00 — Setup
#
# Ce notebook vérifie l'environnement et charge les libs.

# %%
import sys, os
from pathlib import Path

# Add src/ to path
ROOT = Path("..").resolve()
SRC = ROOT / "src"
if str(SRC) not in sys.path:
    sys.path.insert(0, str(SRC))

import numpy as np
import pandas as pd

from utils import get_logger
logger = get_logger("notebook", log_file=str(ROOT/"logs"/"run.log"))

logger.info("Project root: %s", ROOT)
logger.info("Pandas version: %s", pd.__version__)
# Out:
# 2025-12-16 14:04:59,032 | INFO | notebook | Project root: C:\Users\fayca\Downloads\hackathon_gold_project\hackathon_gold_project
# 2025-12-16 14:04:59,035 | INFO | notebook | Pandas version: 2.3.3

# %% [markdown]
# ➡️ Mets `dataset_train.xlsx` à la racine du projet (ou adapte le chemin).
