# %% [markdown]
# # 06 — Multi-asset models comparison (ML vs ML+MerLin)
#
# Objectif :
# 1) Comparer plusieurs modèles **classiques** (Ridge / RandomForest / GBRT) sur **tous les actifs** (toutes les feuilles Excel).
# 2) Ajouter une comparaison **QML hybride** via **MerLin** (embedding) sur une liste d'actifs ciblés.
#
# Métriques :
# - **IC (Spearman)** : métrique principale en finance
# - Directional accuracy
# - MSE (sur score)
#
# ⚠️ Notes :
# - Validation temporelle (TimeSeriesSplit)
# - Scaling du score [-1,1] calibré **sur le train uniquement**
# - MerLin appliqué sur **peu de features** (3–5 max)

# %%
import sys
from pathlib import Path

# Assumes this notebook is inside <project>/notebooks/
ROOT = Path.cwd().parent
SRC = ROOT / "src"
if str(SRC) not in sys.path:
    sys.path.insert(0, str(SRC))

import numpy as np
import pandas as pd

from utils import get_logger
logger = get_logger("multi_asset", log_file=str(ROOT/"logs"/"multi_asset.log"))

logger.info("ROOT=%s", ROOT)
logger.info("SRC=%s (exists=%s)", SRC, SRC.exists())
# Out:
# 2025-12-16 15:11:50,856 | INFO | multi_asset | ROOT=c:\Users\fayca\Downloads\hackathon_gold_project\hackathon_gold_project
# 2025-12-16 15:11:50,859 | INFO | multi_asset | SRC=c:\Users\fayca\Downloads\hackathon_gold_project\hackathon_gold_project\src (exists=True)

# %% [markdown]
# ## 1) Charger la liste des actifs (feuilles Excel)

# %%
import pandas as pd

XLSX = ROOT / "dataset_train.xlsx"
assert XLSX.exists(), f"Excel not found: {XLSX}"

xls = pd.ExcelFile(XLSX, engine="openpyxl")
assets = xls.sheet_names
logger.info("Found %d sheets/assets: %s", len(assets), assets)

assets
# Out:
# 2025-12-16 15:11:53,134 | INFO | multi_asset | Found 9 sheets/assets: ['MSCI world', 'S&P 500 index', 'Euro stoxx 50', 'Dax', 'CAC 40', 'Gold', 'Pétrole', 'Dollar Index', 'EURUSD']
# ['MSCI world',
#  'S&P 500 index',
#  'Euro stoxx 50',
#  'Dax',
#  'CAC 40',
#  'Gold',
#  'Pétrole',
#  'Dollar Index',
#  'EURUSD']

# %% [markdown]
# ## 2) Imports du pipeline (features / labels / splits / modèles / MerLin)

# %%
from data import load_ohlc_from_xlsx
from features import build_features
from labels import add_target_20d_score, fit_score_scaler
from split import time_series_splits
from models import get_baselines
from metrics import mse, directional_accuracy, information_coefficient

from merlin_embedder import MerlinEmbedder
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import Ridge

# %% [markdown]
# ## 3) Paramètres d'expérience

# %%
N_SPLITS = 5
MIN_ROWS = 300  # ignorer les actifs avec trop peu d'historique

# QML : cibler 1-2 actifs max
default_qml = []
for name in ['MSCI world', 'S&P 500 index', 'Euro stoxx 50', 'Dax', 'CAC 40', 'Gold', 'Pétrole', 'Dollar Index', 'EURUSD']:
    if name in assets:
        default_qml.append(name)
if len(default_qml) < 2:
    default_qml = assets[:2]

QML_ASSETS = default_qml

# Features QML (3–5 max)
QML_FEATURES = ["mom_20", "ret_vol_20", "rsi_14", "atr_rel_14"]

logger.info("QML_ASSETS=%s", QML_ASSETS)
logger.info("QML_FEATURES=%s", QML_FEATURES)
# Out:
# 2025-12-16 15:12:00,171 | INFO | multi_asset | QML_ASSETS=['MSCI world', 'S&P 500 index', 'Euro stoxx 50', 'Dax', 'CAC 40', 'Gold', 'Pétrole', 'Dollar Index', 'EURUSD']
# 2025-12-16 15:12:00,173 | INFO | multi_asset | QML_FEATURES=['mom_20', 'ret_vol_20', 'rsi_14', 'atr_rel_14']

# %% [markdown]
# ## 4) Boucle multi-actifs : ML classique + variante MerLin

# %%
all_results = []

for asset in assets:
    try:
        df = load_ohlc_from_xlsx(str(XLSX), sheet_name=asset)
        df = add_target_20d_score(build_features(df), horizon=20)
        df = df.dropna().reset_index(drop=True)

        if len(df) < MIN_ROWS:
            logger.warning("Skip %s (rows=%d < MIN_ROWS=%d)", asset, len(df), MIN_ROWS)
            continue

        exclude = {"Date","Open","High","Low","Close","fut_ret_20","y_score"}
        feature_cols = [c for c in df.columns if c not in exclude]
        X = df[feature_cols].to_numpy()
        fut = df["fut_ret_20"].to_numpy()

        baselines = get_baselines()

        do_qml = asset in QML_ASSETS
        qml_cols = [c for c in QML_FEATURES if c in df.columns]
        X_qml = df[qml_cols].to_numpy() if do_qml and len(qml_cols) >= 2 else None

        for split_id, (tr, te) in enumerate(time_series_splits(len(df), n_splits=N_SPLITS, embargo=0), start=1):
            scale = fit_score_scaler(pd.Series(fut[tr]), std_mult=2.0)
            y_tr = np.clip(fut[tr] / scale, -1.0, 1.0)
            y_te = np.clip(fut[te] / scale, -1.0, 1.0)

            # Classic models
            for spec in baselines:
                model = spec.model
                model.fit(X[tr], y_tr)
                pred = model.predict(X[te])

                all_results.append({
                    "asset": asset,
                    "model": spec.name,
                    "variant": "classic",
                    "split": split_id,
                    "ic": information_coefficient(y_te, pred),
                    "dir_acc": directional_accuracy(y_te, pred),
                    "mse": mse(y_te, pred),
                })

            # MerLin hybrid (ridge on embedding)
            if do_qml and X_qml is not None:
                emb = MerlinEmbedder(n_qubits=min(4, X_qml.shape[1]), n_features_in=X_qml.shape[1])
                Z_tr = emb.fit_transform(X_qml[tr], y_tr)
                Z_te = emb.transform(X_qml[te])

                qml_model = Pipeline([("scaler", StandardScaler()), ("model", Ridge(alpha=1.0))])
                qml_model.fit(Z_tr, y_tr)
                pred_q = qml_model.predict(Z_te)

                all_results.append({
                    "asset": asset,
                    "model": "ridge_merlin",
                    "variant": "qml",
                    "split": split_id,
                    "ic": information_coefficient(y_te, pred_q),
                    "dir_acc": directional_accuracy(y_te, pred_q),
                    "mse": mse(y_te, pred_q),
                    "qml_features": ",".join(qml_cols),
                })

        logger.info("Done asset=%s (rows=%d, features=%d, qml=%s)", asset, len(df), len(feature_cols), do_qml)

    except Exception as e:
        logger.exception("Asset failed: %s | err=%s", asset, e)

results_all = pd.DataFrame(all_results)
logger.info("Total rows in results: %d", len(results_all))
results_all.head()
# Out:
# 2025-12-16 15:12:04,174 | INFO | data | Loading sheet=MSCI world from c:\Users\fayca\Downloads\hackathon_gold_project\hackathon_gold_project\dataset_train.xlsx
# 2025-12-16 15:12:09,395 | INFO | data | Loaded 12387 rows, columns=['Date', 'Open', 'High', 'Low', 'Close', 'smavg_50', 'smavg_100', 'smavg_240']
# 2025-12-16 15:12:09,399 | INFO | features | Building features...
# 2025-12-16 15:12:09,468 | INFO | features | Features built. Total columns=34
# 2025-12-16 15:12:09,520 | INFO | labels | Fitted score scale=0.079461 (std_mult=2.00, std=0.039730)
# 2025-12-16 15:12:21,034 | WARNING | merlin_embedder | MerLin not available in this environment. Falling back to identity embedder. Err=No module named 'merlin'
# 2025-12-16 15:12:21,041 | INFO | labels | Fitted score scale=0.082479 (std_mult=2.00, std=0.041239)
# 2025-12-16 15:12:36,909 | WARNING | merlin_embedder | MerLin not available in this environment. Falling back to identity embedder. Err=No module named 'merlin'
# 2025-12-16 15:12:36,919 | INFO | labels | Fitted score scale=0.078186 (std_mult=2.00, std=0.039093)
# 2025-12-16 15:13:01,595 | WARNING | merlin_embedder | MerLin not available in this environment. Falling back to identity embedder. Err=No module named 'merlin'
# 2025-12-16 15:13:01,600 | INFO | labels | Fitted score scale=0.081490 (std_mult=2.00, std=0.040745)
# 2025-12-16 15:13:35,780 | WARNING | merlin_embedder | MerLin not available in this environment. Falling back to identity embedder. Err=No module named 'merlin'
# 2025-12-16 15:13:35,786 | INFO | labels | Fitted score scale=0.085597 (std_mult=2.00, std=0.042798)
# 2025-12-16 15:14:19,795 | WARNING | merlin_embedder | MerLin not available in this environment. Falling back to identity embedder. Err=No module named 'merlin'
# 2025-12-16 15:14:19,800 | INFO | multi_asset | Done asset=MSCI world (rows=12120, features=29, qml=True)
# 2025-12-16 15:14:19,801 | INFO | data | Loading sheet=S&P 500 index from c:\Users\fayca\Downloads\hackathon_gold_project\hackathon_gold_project\dataset_train.xlsx
# 2025-12-16 15:14:21,007 | INFO | data | Loaded 12361 rows, columns=['Date', 'Open', 'High', 'Low', 'Close', 'smavg_50', 'smavg_100', 'smavg_240']
# 2025-12-16 15:14:21,009 | INFO | features | Building features...
# 2025-12-16 15:14:21,036 | INFO | features | Features built. Total columns=34
# 2025-12-16 15:14:21,055 | INFO | labels | Fitted score scale=0.089945 (std_mult=2.00, std=0.044972)
# 2025-12-16 15:14:28,992 | WARNING | merlin_embedder | MerLin not available in this environment. Falling back to identity embedder. Err=No module named 'merlin'
# 2025-12-16 15:14:28,997 | INFO | labels | Fitted score scale=0.087216 (std_mult=2.00, std=0.043608)
# 2025-12-16 15:14:45,401 | WARNING | merlin_embedder | MerLin not available in this environment. Falling back to identity embedder. Err=No module named 'merlin'
# 2025-12-16 15:14:45,407 | INFO | labels | Fitted score scale=0.086510 (std_mult=2.00, std=0.043255)
# 2025-12-16 15:15:11,861 | WARNING | merlin_embedder | MerLin not available in this environment. Falling back to identity embedder. Err=No module named 'merlin'
# 2025-12-16 15:15:11,867 | INFO | labels | Fitted score scale=0.089311 (std_mult=2.00, std=0.044655)
# 2025-12-16 15:15:47,621 | WARNING | merlin_embedder | MerLin not available in this environment. Falling back to identity embedder. Err=No module named 'merlin'
# 2025-12-16 15:15:47,627 | INFO | labels | Fitted score scale=0.090758 (std_mult=2.00, std=0.045379)
# 2025-12-16 15:16:34,023 | WARNING | merlin_embedder | MerLin not available in this environment. Falling back to identity embedder. Err=No module named 'merlin'
# 2025-12-16 15:16:34,029 | INFO | multi_asset | Done asset=S&P 500 index (rows=12101, features=29, qml=True)
# 2025-12-16 15:16:34,030 | INFO | data | Loading sheet=Euro stoxx 50 from c:\Users\fayca\Downloads\hackathon_gold_project\hackathon_gold_project\dataset_train.xlsx
# 2025-12-16 15:16:34,810 | INFO | data | Loaded 8251 rows, columns=['Date', 'Open', 'High', 'Low', 'Close', 'smavg_50', 'smavg_100', 'smavg_240']
# 2025-12-16 15:16:34,811 | INFO | features | Building features...
# 2025-12-16 15:16:34,832 | INFO | features | Features built. Total columns=34
# 2025-12-16 15:16:34,844 | INFO | labels | Fitted score scale=0.084501 (std_mult=2.00, std=0.042250)
# 2025-12-16 15:16:39,700 | WARNING | merlin_embedder | MerLin not available in this environment. Falling back to identity embedder. Err=No module named 'merlin'
# 2025-12-16 15:16:39,705 | INFO | labels | Fitted score scale=0.081414 (std_mult=2.00, std=0.040707)
# 2025-12-16 15:16:51,325 | WARNING | merlin_embedder | MerLin not available in this environment. Falling back to identity embedder. Err=No module named 'merlin'
# 2025-12-16 15:16:51,330 | INFO | labels | Fitted score scale=0.107100 (std_mult=2.00, std=0.053550)
# 2025-12-16 15:17:07,481 | WARNING | merlin_embedder | MerLin not available in this environment. Falling back to identity embedder. Err=No module named 'merlin'
# 2025-12-16 15:17:07,486 | INFO | labels | Fitted score scale=0.100947 (std_mult=2.00, std=0.050474)
# 2025-12-16 15:17:35,601 | WARNING | merlin_embedder | MerLin not available in this environment. Falling back to identity embedder. Err=No module named 'merlin'
# 2025-12-16 15:17:35,611 | INFO | labels | Fitted score scale=0.107711 (std_mult=2.00, std=0.053856)
# 2025-12-16 15:18:12,556 | WARNING | merlin_embedder | MerLin not available in this environment. Falling back to identity embedder. Err=No module named 'merlin'
# 2025-12-16 15:18:12,565 | INFO | multi_asset | Done asset=Euro stoxx 50 (rows=7992, features=29, qml=True)
# 2025-12-16 15:18:12,567 | INFO | data | Loading sheet=Dax from c:\Users\fayca\Downloads\hackathon_gold_project\hackathon_gold_project\dataset_train.xlsx
# 2025-12-16 15:18:14,581 | INFO | data | Loaded 12337 rows, columns=['Date', 'Open', 'High', 'Low', 'Close', 'smavg_50', 'smavg_100', 'smavg_240']
# 2025-12-16 15:18:14,584 | INFO | features | Building features...
# 2025-12-16 15:18:14,612 | INFO | features | Features built. Total columns=34
# 2025-12-16 15:18:14,634 | INFO | labels | Fitted score scale=0.087583 (std_mult=2.00, std=0.043791)
# 2025-12-16 15:18:23,076 | WARNING | merlin_embedder | MerLin not available in this environment. Falling back to identity embedder. Err=No module named 'merlin'
# 2025-12-16 15:18:23,085 | INFO | labels | Fitted score scale=0.088613 (std_mult=2.00, std=0.044306)
# 2025-12-16 15:18:42,208 | WARNING | merlin_embedder | MerLin not available in this environment. Falling back to identity embedder. Err=No module named 'merlin'
# 2025-12-16 15:18:42,216 | INFO | labels | Fitted score scale=0.097988 (std_mult=2.00, std=0.048994)
# 2025-12-16 15:19:09,362 | WARNING | merlin_embedder | MerLin not available in this environment. Falling back to identity embedder. Err=No module named 'merlin'
# 2025-12-16 15:19:09,367 | INFO | labels | Fitted score scale=0.110220 (std_mult=2.00, std=0.055110)
# 2025-12-16 15:19:46,594 | WARNING | merlin_embedder | MerLin not available in this environment. Falling back to identity embedder. Err=No module named 'merlin'
# 2025-12-16 15:19:46,600 | INFO | labels | Fitted score scale=0.111067 (std_mult=2.00, std=0.055534)
# 2025-12-16 15:20:42,154 | WARNING | merlin_embedder | MerLin not available in this environment. Falling back to identity embedder. Err=No module named 'merlin'
# 2025-12-16 15:20:42,161 | INFO | multi_asset | Done asset=Dax (rows=12076, features=29, qml=True)
# 2025-12-16 15:20:42,162 | INFO | data | Loading sheet=CAC 40 from c:\Users\fayca\Downloads\hackathon_gold_project\hackathon_gold_project\dataset_train.xlsx
# 2025-12-16 15:20:43,209 | INFO | data | Loaded 7975 rows, columns=['Date', 'Open', 'High', 'Low', 'Close', 'smavg_50', 'smavg_100', 'smavg_240']
# 2025-12-16 15:20:43,211 | INFO | features | Building features...
# 2025-12-16 15:20:43,231 | INFO | features | Features built. Total columns=34
# 2025-12-16 15:20:43,248 | INFO | labels | Fitted score scale=0.105891 (std_mult=2.00, std=0.052945)
# 2025-12-16 15:20:49,789 | WARNING | merlin_embedder | MerLin not available in this environment. Falling back to identity embedder. Err=No module named 'merlin'
# 2025-12-16 15:20:49,794 | INFO | labels | Fitted score scale=0.106567 (std_mult=2.00, std=0.053284)
# 2025-12-16 15:21:01,840 | WARNING | merlin_embedder | MerLin not available in this environment. Falling back to identity embedder. Err=No module named 'merlin'
# 2025-12-16 15:21:01,854 | INFO | labels | Fitted score scale=0.114745 (std_mult=2.00, std=0.057373)
# 2025-12-16 15:21:23,907 | WARNING | merlin_embedder | MerLin not available in this environment. Falling back to identity embedder. Err=No module named 'merlin'
# 2025-12-16 15:21:23,913 | INFO | labels | Fitted score scale=0.110302 (std_mult=2.00, std=0.055151)
# 2025-12-16 15:21:48,258 | WARNING | merlin_embedder | MerLin not available in this environment. Falling back to identity embedder. Err=No module named 'merlin'
# 2025-12-16 15:21:48,263 | INFO | labels | Fitted score scale=0.111140 (std_mult=2.00, std=0.055570)
# 2025-12-16 15:22:21,911 | WARNING | merlin_embedder | MerLin not available in this environment. Falling back to identity embedder. Err=No module named 'merlin'
# 2025-12-16 15:22:21,920 | INFO | multi_asset | Done asset=CAC 40 (rows=7716, features=29, qml=True)
# 2025-12-16 15:22:21,921 | INFO | data | Loading sheet=Gold from c:\Users\fayca\Downloads\hackathon_gold_project\hackathon_gold_project\dataset_train.xlsx
# 2025-12-16 15:22:23,230 | INFO | data | Loaded 11340 rows, columns=['Date', 'Open', 'High', 'Low', 'Close', 'smavg_50', 'smavg_100', 'smavg_240']
# 2025-12-16 15:22:23,234 | INFO | features | Building features...
# 2025-12-16 15:22:23,255 | INFO | features | Features built. Total columns=34
# 2025-12-16 15:22:23,270 | INFO | labels | Fitted score scale=0.192158 (std_mult=2.00, std=0.096079)
# 2025-12-16 15:22:35,185 | WARNING | merlin_embedder | MerLin not available in this environment. Falling back to identity embedder. Err=No module named 'merlin'
# 2025-12-16 15:22:35,192 | INFO | labels | Fitted score scale=0.151396 (std_mult=2.00, std=0.075698)
# 2025-12-16 15:22:55,635 | WARNING | merlin_embedder | MerLin not available in this environment. Falling back to identity embedder. Err=No module named 'merlin'
# 2025-12-16 15:22:55,644 | INFO | labels | Fitted score scale=0.127992 (std_mult=2.00, std=0.063996)
# 2025-12-16 15:23:25,081 | WARNING | merlin_embedder | MerLin not available in this environment. Falling back to identity embedder. Err=No module named 'merlin'
# 2025-12-16 15:23:25,090 | INFO | labels | Fitted score scale=0.118446 (std_mult=2.00, std=0.059223)
# 2025-12-16 15:23:57,690 | WARNING | merlin_embedder | MerLin not available in this environment. Falling back to identity embedder. Err=No module named 'merlin'
# 2025-12-16 15:23:57,695 | INFO | labels | Fitted score scale=0.117416 (std_mult=2.00, std=0.058708)
# 2025-12-16 15:24:36,469 | WARNING | merlin_embedder | MerLin not available in this environment. Falling back to identity embedder. Err=No module named 'merlin'
# 2025-12-16 15:24:36,474 | INFO | multi_asset | Done asset=Gold (rows=11081, features=29, qml=True)
# 2025-12-16 15:24:36,475 | INFO | data | Loading sheet=Pétrole from c:\Users\fayca\Downloads\hackathon_gold_project\hackathon_gold_project\dataset_train.xlsx
# 2025-12-16 15:24:37,451 | INFO | data | Loaded 8960 rows, columns=['Date', 'Open', 'High', 'Low', 'Close', 'smavg_50', 'smavg_100', 'smavg_240', 'Open Interest', 'SMAVG (15)']
# 2025-12-16 15:24:37,452 | INFO | features | Building features...
# 2025-12-16 15:24:37,473 | INFO | features | Features built. Total columns=36
# 2025-12-16 15:24:37,491 | INFO | labels | Fitted score scale=0.191108 (std_mult=2.00, std=0.095554)
# 2025-12-16 15:24:43,474 | WARNING | merlin_embedder | MerLin not available in this environment. Falling back to identity embedder. Err=No module named 'merlin'
# 2025-12-16 15:24:43,479 | INFO | labels | Fitted score scale=0.193799 (std_mult=2.00, std=0.096900)
# 2025-12-16 15:24:55,559 | WARNING | merlin_embedder | MerLin not available in this environment. Falling back to identity embedder. Err=No module named 'merlin'
# 2025-12-16 15:24:55,565 | INFO | labels | Fitted score scale=0.192945 (std_mult=2.00, std=0.096473)
# 2025-12-16 15:25:19,478 | WARNING | merlin_embedder | MerLin not available in this environment. Falling back to identity embedder. Err=No module named 'merlin'
# 2025-12-16 15:25:19,533 | INFO | labels | Fitted score scale=0.190634 (std_mult=2.00, std=0.095317)
# 2025-12-16 15:25:46,279 | WARNING | merlin_embedder | MerLin not available in this environment. Falling back to identity embedder. Err=No module named 'merlin'
# 2025-12-16 15:25:46,285 | INFO | labels | Fitted score scale=0.194869 (std_mult=2.00, std=0.097435)
# 2025-12-16 15:26:20,678 | WARNING | merlin_embedder | MerLin not available in this environment. Falling back to identity embedder. Err=No module named 'merlin'
# 2025-12-16 15:26:20,683 | INFO | multi_asset | Done asset=Pétrole (rows=8630, features=31, qml=True)
# 2025-12-16 15:26:20,685 | INFO | data | Loading sheet=Dollar Index from c:\Users\fayca\Downloads\hackathon_gold_project\hackathon_gold_project\dataset_train.xlsx
# 2025-12-16 15:26:22,023 | INFO | data | Loaded 12271 rows, columns=['Date', 'Open', 'High', 'Low', 'Close', 'smavg_50', 'smavg_100', 'smavg_240']
# 2025-12-16 15:26:22,025 | INFO | features | Building features...
# 2025-12-16 15:26:22,057 | INFO | features | Features built. Total columns=34
# 2025-12-16 15:26:22,077 | INFO | labels | Fitted score scale=0.041297 (std_mult=2.00, std=0.020648)
# 2025-12-16 15:26:29,823 | WARNING | merlin_embedder | MerLin not available in this environment. Falling back to identity embedder. Err=No module named 'merlin'
# 2025-12-16 15:26:29,828 | INFO | labels | Fitted score scale=0.051192 (std_mult=2.00, std=0.025596)
# 2025-12-16 15:26:46,105 | WARNING | merlin_embedder | MerLin not available in this environment. Falling back to identity embedder. Err=No module named 'merlin'
# 2025-12-16 15:26:46,110 | INFO | labels | Fitted score scale=0.051868 (std_mult=2.00, std=0.025934)
# 2025-12-16 15:27:11,300 | WARNING | merlin_embedder | MerLin not available in this environment. Falling back to identity embedder. Err=No module named 'merlin'
# 2025-12-16 15:27:11,310 | INFO | labels | Fitted score scale=0.049715 (std_mult=2.00, std=0.024858)
# 2025-12-16 15:27:47,802 | WARNING | merlin_embedder | MerLin not available in this environment. Falling back to identity embedder. Err=No module named 'merlin'
# 2025-12-16 15:27:47,808 | INFO | labels | Fitted score scale=0.050064 (std_mult=2.00, std=0.025032)
# 2025-12-16 15:28:32,937 | WARNING | merlin_embedder | MerLin not available in this environment. Falling back to identity embedder. Err=No module named 'merlin'
# 2025-12-16 15:28:32,943 | INFO | multi_asset | Done asset=Dollar Index (rows=12011, features=29, qml=True)
# 2025-12-16 15:28:32,944 | INFO | data | Loading sheet=EURUSD from c:\Users\fayca\Downloads\hackathon_gold_project\hackathon_gold_project\dataset_train.xlsx
# 2025-12-16 15:28:34,090 | INFO | data | Loaded 11288 rows, columns=['Date', 'Open', 'High', 'Low', 'Close', 'smavg_50', 'smavg_100', 'smavg_240']
# 2025-12-16 15:28:34,092 | INFO | features | Building features...
# 2025-12-16 15:28:34,117 | INFO | features | Features built. Total columns=34
# 2025-12-16 15:28:34,138 | INFO | labels | Fitted score scale=0.052527 (std_mult=2.00, std=0.026263)
# 2025-12-16 15:28:41,541 | WARNING | merlin_embedder | MerLin not available in this environment. Falling back to identity embedder. Err=No module named 'merlin'
# 2025-12-16 15:28:41,546 | INFO | labels | Fitted score scale=0.060090 (std_mult=2.00, std=0.030045)
# 2025-12-16 15:28:55,911 | WARNING | merlin_embedder | MerLin not available in this environment. Falling back to identity embedder. Err=No module named 'merlin'
# 2025-12-16 15:28:55,918 | INFO | labels | Fitted score scale=0.059816 (std_mult=2.00, std=0.029908)
# 2025-12-16 15:29:18,013 | WARNING | merlin_embedder | MerLin not available in this environment. Falling back to identity embedder. Err=No module named 'merlin'
# 2025-12-16 15:29:18,019 | INFO | labels | Fitted score scale=0.058969 (std_mult=2.00, std=0.029484)
# 2025-12-16 15:29:48,599 | WARNING | merlin_embedder | MerLin not available in this environment. Falling back to identity embedder. Err=No module named 'merlin'
# 2025-12-16 15:29:48,606 | INFO | labels | Fitted score scale=0.059790 (std_mult=2.00, std=0.029895)
# 2025-12-16 15:30:29,817 | WARNING | merlin_embedder | MerLin not available in this environment. Falling back to identity embedder. Err=No module named 'merlin'
# 2025-12-16 15:30:29,823 | INFO | multi_asset | Done asset=EURUSD (rows=11029, features=29, qml=True)
# 2025-12-16 15:30:29,870 | INFO | multi_asset | Total rows in results: 180
#         asset          model  variant  split        ic   dir_acc       mse  \
# 0  MSCI world          ridge  classic      1  0.058053  0.430693  0.685453
# 1  MSCI world  random_forest  classic      1  0.008372  0.394554  0.946715
# 2  MSCI world           gbrt  classic      1 -0.075678  0.373762  1.505200
# 3  MSCI world   ridge_merlin      qml      1  0.080159  0.594059  0.233141
# 4  MSCI world          ridge  classic      2 -0.053449  0.568317  0.200035
#
#                           qml_features
# 0                                  NaN
# 1                                  NaN
# 2                                  NaN
# 3  mom_20,ret_vol_20,rsi_14,atr_rel_14
# 4                                  NaN

# %% [markdown]
# ## 5) Résumé (moyenne sur splits)

# %%
summary = (
    results_all
    .groupby(["asset","model","variant"])
    .agg(ic=("ic","mean"), dir_acc=("dir_acc","mean"), mse=("mse","mean"))
    .reset_index()
    .sort_values(["asset","ic"], ascending=[True, False])
)
summary
# Out:
#             asset          model  variant        ic   dir_acc       mse
# 0          CAC 40           gbrt  classic  0.104343  0.540435  0.367380
# 1          CAC 40  random_forest  classic  0.054719  0.524883  0.410935
# 3          CAC 40   ridge_merlin      qml  0.047535  0.559409  0.206009
# 2          CAC 40          ridge  classic  0.013629  0.471073  0.705627
# 7             Dax   ridge_merlin      qml  0.060737  0.576441  0.250892
# 5             Dax  random_forest  classic  0.030571  0.478231  0.442123
# 4             Dax           gbrt  classic  0.021556  0.468191  0.522334
# 6             Dax          ridge  classic -0.010995  0.465308  0.480299
# 9    Dollar Index  random_forest  classic  0.106363  0.500950  0.313029
# 8    Dollar Index           gbrt  classic  0.093039  0.503948  0.365078
# 10   Dollar Index          ridge  classic  0.067493  0.506947  0.267195
# 11   Dollar Index   ridge_merlin      qml  0.030563  0.515142  0.240597
# 12         EURUSD           gbrt  classic  0.088047  0.510120  0.306273
# 13         EURUSD  random_forest  classic  0.073521  0.519260  0.267576
# 15         EURUSD   ridge_merlin      qml  0.042227  0.508487  0.229621
# 14         EURUSD          ridge  classic  0.006659  0.494015  0.250469
# 19  Euro stoxx 50   ridge_merlin      qml  0.058482  0.569219  0.264522
# 18  Euro stoxx 50          ridge  classic  0.057355  0.489790  0.831916
# 16  Euro stoxx 50           gbrt  classic  0.041115  0.495796  0.537068
# 17  Euro stoxx 50  random_forest  classic  0.036334  0.494595  0.532854
# 22           Gold          ridge  classic  0.082537  0.481798  0.210531
# 20           Gold           gbrt  classic  0.055438  0.476706  0.221100
# 21           Gold  random_forest  classic  0.015276  0.441062  0.205150
# 23           Gold   ridge_merlin      qml -0.002411  0.465114  0.105312
# 24     MSCI world           gbrt  classic  0.088124  0.461980  0.620867
# 25     MSCI world  random_forest  classic  0.076511  0.460693  0.538276
# 26     MSCI world          ridge  classic  0.039898  0.515842  0.313962
# 27     MSCI world   ridge_merlin      qml  0.014982  0.593861  0.209817
# 30        Pétrole          ridge  classic  0.141864  0.518915  0.307673
# 28        Pétrole           gbrt  classic  0.118138  0.514186  0.397944
# 29        Pétrole  random_forest  classic  0.101556  0.510431  0.311343
# 31        Pétrole   ridge_merlin      qml -0.009617  0.519054  0.214584
# 32  S&P 500 index           gbrt  classic  0.130109  0.443849  0.434092
# 34  S&P 500 index          ridge  classic  0.107859  0.456548  0.409479
# 33  S&P 500 index  random_forest  classic  0.098040  0.481548  0.250164
# 35  S&P 500 index   ridge_merlin      qml  0.046365  0.615476  0.189535

# %% [markdown]
# ## 6) Comparaison Classic vs QML sur les actifs ciblés

# %%
qml_compare = summary[summary["asset"].isin(QML_ASSETS)].copy()
qml_compare.sort_values(["asset","variant","ic"], ascending=[True, True, False])
# Out:
#             asset          model  variant        ic   dir_acc       mse
# 0          CAC 40           gbrt  classic  0.104343  0.540435  0.367380
# 1          CAC 40  random_forest  classic  0.054719  0.524883  0.410935
# 2          CAC 40          ridge  classic  0.013629  0.471073  0.705627
# 3          CAC 40   ridge_merlin      qml  0.047535  0.559409  0.206009
# 5             Dax  random_forest  classic  0.030571  0.478231  0.442123
# 4             Dax           gbrt  classic  0.021556  0.468191  0.522334
# 6             Dax          ridge  classic -0.010995  0.465308  0.480299
# 7             Dax   ridge_merlin      qml  0.060737  0.576441  0.250892
# 9    Dollar Index  random_forest  classic  0.106363  0.500950  0.313029
# 8    Dollar Index           gbrt  classic  0.093039  0.503948  0.365078
# 10   Dollar Index          ridge  classic  0.067493  0.506947  0.267195
# 11   Dollar Index   ridge_merlin      qml  0.030563  0.515142  0.240597
# 12         EURUSD           gbrt  classic  0.088047  0.510120  0.306273
# 13         EURUSD  random_forest  classic  0.073521  0.519260  0.267576
# 14         EURUSD          ridge  classic  0.006659  0.494015  0.250469
# 15         EURUSD   ridge_merlin      qml  0.042227  0.508487  0.229621
# 18  Euro stoxx 50          ridge  classic  0.057355  0.489790  0.831916
# 16  Euro stoxx 50           gbrt  classic  0.041115  0.495796  0.537068
# 17  Euro stoxx 50  random_forest  classic  0.036334  0.494595  0.532854
# 19  Euro stoxx 50   ridge_merlin      qml  0.058482  0.569219  0.264522
# 22           Gold          ridge  classic  0.082537  0.481798  0.210531
# 20           Gold           gbrt  classic  0.055438  0.476706  0.221100
# 21           Gold  random_forest  classic  0.015276  0.441062  0.205150
# 23           Gold   ridge_merlin      qml -0.002411  0.465114  0.105312
# 24     MSCI world           gbrt  classic  0.088124  0.461980  0.620867
# 25     MSCI world  random_forest  classic  0.076511  0.460693  0.538276
# 26     MSCI world          ridge  classic  0.039898  0.515842  0.313962
# 27     MSCI world   ridge_merlin      qml  0.014982  0.593861  0.209817
# 30        Pétrole          ridge  classic  0.141864  0.518915  0.307673
# 28        Pétrole           gbrt  classic  0.118138  0.514186  0.397944
# 29        Pétrole  random_forest  classic  0.101556  0.510431  0.311343
# 31        Pétrole   ridge_merlin      qml -0.009617  0.519054  0.214584
# 32  S&P 500 index           gbrt  classic  0.130109  0.443849  0.434092
# 34  S&P 500 index          ridge  classic  0.107859  0.456548  0.409479
# 33  S&P 500 index  random_forest  classic  0.098040  0.481548  0.250164
# 35  S&P 500 index   ridge_merlin      qml  0.046365  0.615476  0.189535

# %% [markdown]
# ## 7) Export des résultats

# %%
out_dir = ROOT / "outputs"
out_dir.mkdir(exist_ok=True)

raw_path = out_dir / "results_all_assets_models_with_merlin_raw.csv"
sum_path = out_dir / "results_all_assets_models_with_merlin_summary.csv"

results_all.to_csv(raw_path, index=False)
summary.to_csv(sum_path, index=False)

logger.info("Exported raw: %s", raw_path)
logger.info("Exported summary: %s", sum_path)

(raw_path, sum_path)
# Out:
# 2025-12-16 15:30:30,114 | INFO | multi_asset | Exported raw: c:\Users\fayca\Downloads\hackathon_gold_project\hackathon_gold_project\outputs\results_all_assets_models_with_merlin_raw.csv
# 2025-12-16 15:30:30,117 | INFO | multi_asset | Exported summary: c:\Users\fayca\Downloads\hackathon_gold_project\hackathon_gold_project\outputs\results_all_assets_models_with_merlin_summary.csv
# (WindowsPath('c:/Users/fayca/Downloads/hackathon_gold_project/hackathon_gold_project/outputs/results_all_assets_models_with_merlin_raw.csv'),
#  WindowsPath('c:/Users/fayca/Downloads/hackathon_gold_project/hackathon_gold_project/outputs/results_all_assets_models_with_merlin_summary.csv'))

# %% [markdown]
# ## Notes soutenance
# - IC est la métrique principale.
# - Si `ridge_merlin` ≈ `ridge` : résultat neutre (OK).
# - Si `ridge_merlin` > `ridge` sur 1-2 actifs : petit gain (bonus).
# - Si GBRT reste meilleur : conclusion honnête (classique très compétitif).
