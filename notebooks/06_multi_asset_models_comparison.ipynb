# %%
import numpy as np
import pandas as pd

from utils import get_logger

from data import load_ohlc_from_xlsx
from features import build_features
from labels import add_target_20d_score, fit_score_scaler, apply_score
from split import time_series_splits
from models import get_baselines
from metrics import mse, directional_accuracy, information_coefficient

# %%
import pandas as pd
import sys
from pathlib import Path

ROOT = Path("..").resolve()
SRC = ROOT / "src"
if str(SRC) not in sys.path:
    sys.path.insert(0, str(SRC))
xls = pd.ExcelFile(ROOT / "dataset_train.xlsx", engine="openpyxl")
assets = xls.sheet_names
assets
# Out:
# ['MSCI world',
#  'S&P 500 index',
#  'Euro stoxx 50',
#  'Dax',
#  'CAC 40',
#  'Gold',
#  'Pétrole',
#  'Dollar Index',
#  'EURUSD']

# %%
all_results = []

for asset in assets:
    try:
        df = load_ohlc_from_xlsx(ROOT/"dataset_train.xlsx", sheet_name=asset)
        df = add_target_20d_score(build_features(df), horizon=20)
        df = df.dropna().reset_index(drop=True)

        if len(df) < 300:
            continue  # pas assez de données

        exclude = {"Date","Open","High","Low","Close","fut_ret_20","y_score"}
        feature_cols = [c for c in df.columns if c not in exclude]

        X = df[feature_cols].to_numpy()
        future_ret = df["fut_ret_20"].to_numpy()

        for split_id, (tr, te) in enumerate(time_series_splits(len(df), n_splits=5), start=1):
            scale = fit_score_scaler(pd.Series(future_ret[tr]), std_mult=2.0)
            y_tr = (future_ret[tr] / scale).clip(-1, 1)
            y_te = (future_ret[te] / scale).clip(-1, 1)

            for spec in get_baselines():
                model = spec.model
                model.fit(X[tr], y_tr)
                pred = model.predict(X[te])

                all_results.append({
                    "asset": asset,
                    "model": spec.name,
                    "ic": information_coefficient(y_te, pred),
                    "dir_acc": directional_accuracy(y_te, pred),
                    "mse": mse(y_te, pred)
                })

    except Exception as e:
        print(f"❌ {asset} failed: {e}")

results_all = pd.DataFrame(all_results)
results_all
# Out:
# 2025-12-15 16:37:14,316 | INFO | data | Loading sheet=MSCI world from C:\Users\fayca\Downloads\hackathon_gold_project\hackathon_gold_project\dataset_train.xlsx
# 2025-12-15 16:37:16,114 | INFO | data | Loaded 12387 rows, columns=['Date', 'Open', 'High', 'Low', 'Close', 'smavg_50', 'smavg_100', 'smavg_240']
# 2025-12-15 16:37:16,116 | INFO | features | Building features...
# 2025-12-15 16:37:16,150 | INFO | features | Features built. Total columns=34
# 2025-12-15 16:37:16,181 | INFO | labels | Fitted score scale=0.079461 (std_mult=2.00, std=0.039730)
# 2025-12-15 16:37:24,723 | INFO | labels | Fitted score scale=0.082479 (std_mult=2.00, std=0.041239)
# 2025-12-15 16:37:41,123 | INFO | labels | Fitted score scale=0.078186 (std_mult=2.00, std=0.039093)
# 2025-12-15 16:38:07,047 | INFO | labels | Fitted score scale=0.081490 (std_mult=2.00, std=0.040745)
# 2025-12-15 16:38:42,563 | INFO | labels | Fitted score scale=0.085597 (std_mult=2.00, std=0.042798)
# 2025-12-15 16:39:27,603 | INFO | data | Loading sheet=S&P 500 index from C:\Users\fayca\Downloads\hackathon_gold_project\hackathon_gold_project\dataset_train.xlsx
# 2025-12-15 16:39:28,887 | INFO | data | Loaded 12361 rows, columns=['Date', 'Open', 'High', 'Low', 'Close', 'smavg_50', 'smavg_100', 'smavg_240']
# 2025-12-15 16:39:28,890 | INFO | features | Building features...
# 2025-12-15 16:39:28,919 | INFO | features | Features built. Total columns=34
# 2025-12-15 16:39:28,951 | INFO | labels | Fitted score scale=0.089945 (std_mult=2.00, std=0.044972)
# 2025-12-15 16:39:37,343 | INFO | labels | Fitted score scale=0.087216 (std_mult=2.00, std=0.043608)
# 2025-12-15 16:39:54,062 | INFO | labels | Fitted score scale=0.086510 (std_mult=2.00, std=0.043255)
# 2025-12-15 16:40:20,906 | INFO | labels | Fitted score scale=0.089311 (std_mult=2.00, std=0.044655)
# 2025-12-15 16:40:59,896 | INFO | labels | Fitted score scale=0.090758 (std_mult=2.00, std=0.045379)
# 2025-12-15 16:41:47,378 | INFO | data | Loading sheet=Euro stoxx 50 from C:\Users\fayca\Downloads\hackathon_gold_project\hackathon_gold_project\dataset_train.xlsx
# 2025-12-15 16:41:48,247 | INFO | data | Loaded 8251 rows, columns=['Date', 'Open', 'High', 'Low', 'Close', 'smavg_50', 'smavg_100', 'smavg_240']
# 2025-12-15 16:41:48,248 | INFO | features | Building features...
# 2025-12-15 16:41:48,276 | INFO | features | Features built. Total columns=34
# 2025-12-15 16:41:48,297 | INFO | labels | Fitted score scale=0.084501 (std_mult=2.00, std=0.042250)
# 2025-12-15 16:41:53,618 | INFO | labels | Fitted score scale=0.081414 (std_mult=2.00, std=0.040707)
# 2025-12-15 16:42:04,164 | INFO | labels | Fitted score scale=0.107100 (std_mult=2.00, std=0.053550)
# 2025-12-15 16:42:22,302 | INFO | labels | Fitted score scale=0.100947 (std_mult=2.00, std=0.050474)
# 2025-12-15 16:42:45,273 | INFO | labels | Fitted score scale=0.107711 (std_mult=2.00, std=0.053856)
# 2025-12-15 16:43:14,096 | INFO | data | Loading sheet=Dax from C:\Users\fayca\Downloads\hackathon_gold_project\hackathon_gold_project\dataset_train.xlsx
# 2025-12-15 16:43:15,268 | INFO | data | Loaded 12337 rows, columns=['Date', 'Open', 'High', 'Low', 'Close', 'smavg_50', 'smavg_100', 'smavg_240']
# 2025-12-15 16:43:15,272 | INFO | features | Building features...
# 2025-12-15 16:43:15,297 | INFO | features | Features built. Total columns=34
# 2025-12-15 16:43:15,316 | INFO | labels | Fitted score scale=0.087583 (std_mult=2.00, std=0.043791)
# 2025-12-15 16:43:23,296 | INFO | labels | Fitted score scale=0.088613 (std_mult=2.00, std=0.044306)
# 2025-12-15 16:43:39,695 | INFO | labels | Fitted score scale=0.097988 (std_mult=2.00, std=0.048994)
# 2025-12-15 16:44:06,046 | INFO | labels | Fitted score scale=0.110220 (std_mult=2.00, std=0.055110)
# 2025-12-15 16:44:43,343 | INFO | labels | Fitted score scale=0.111067 (std_mult=2.00, std=0.055534)
# 2025-12-15 16:46:02,074 | INFO | data | Loading sheet=CAC 40 from C:\Users\fayca\Downloads\hackathon_gold_project\hackathon_gold_project\dataset_train.xlsx
# 2025-12-15 16:46:04,219 | INFO | data | Loaded 7975 rows, columns=['Date', 'Open', 'High', 'Low', 'Close', 'smavg_50', 'smavg_100', 'smavg_240']
# 2025-12-15 16:46:04,220 | INFO | features | Building features...
# 2025-12-15 16:46:04,283 | INFO | features | Features built. Total columns=34
# 2025-12-15 16:46:04,322 | INFO | labels | Fitted score scale=0.105891 (std_mult=2.00, std=0.052945)
# 2025-12-15 16:46:11,441 | INFO | labels | Fitted score scale=0.106567 (std_mult=2.00, std=0.053284)
# 2025-12-15 16:46:23,132 | INFO | labels | Fitted score scale=0.114745 (std_mult=2.00, std=0.057373)
# 2025-12-15 16:46:46,800 | INFO | labels | Fitted score scale=0.110302 (std_mult=2.00, std=0.055151)
# 2025-12-15 16:47:11,180 | INFO | labels | Fitted score scale=0.111140 (std_mult=2.00, std=0.055570)
# 2025-12-15 16:47:48,878 | INFO | data | Loading sheet=Gold from C:\Users\fayca\Downloads\hackathon_gold_project\hackathon_gold_project\dataset_train.xlsx
# 2025-12-15 16:47:52,397 | INFO | data | Loaded 11340 rows, columns=['Date', 'Open', 'High', 'Low', 'Close', 'smavg_50', 'smavg_100', 'smavg_240']
# 2025-12-15 16:47:52,401 | INFO | features | Building features...
# 2025-12-15 16:47:52,463 | INFO | features | Features built. Total columns=34
# 2025-12-15 16:47:52,493 | INFO | labels | Fitted score scale=0.192158 (std_mult=2.00, std=0.096079)
# 2025-12-15 16:48:13,762 | INFO | labels | Fitted score scale=0.151396 (std_mult=2.00, std=0.075698)
# 2025-12-15 16:48:39,980 | INFO | labels | Fitted score scale=0.127992 (std_mult=2.00, std=0.063996)
# 2025-12-15 16:49:15,045 | INFO | labels | Fitted score scale=0.118446 (std_mult=2.00, std=0.059223)
# 2025-12-15 16:50:14,761 | INFO | labels | Fitted score scale=0.117416 (std_mult=2.00, std=0.058708)
# 2025-12-15 16:51:34,941 | INFO | data | Loading sheet=Pétrole from C:\Users\fayca\Downloads\hackathon_gold_project\hackathon_gold_project\dataset_train.xlsx
# 2025-12-15 16:51:36,886 | INFO | data | Loaded 8960 rows, columns=['Date', 'Open', 'High', 'Low', 'Close', 'smavg_50', 'smavg_100', 'smavg_240', 'Open Interest', 'SMAVG (15)']
# 2025-12-15 16:51:36,889 | INFO | features | Building features...
# 2025-12-15 16:51:36,960 | INFO | features | Features built. Total columns=36
# 2025-12-15 16:51:36,986 | INFO | labels | Fitted score scale=0.191108 (std_mult=2.00, std=0.095554)
# 2025-12-15 16:51:45,378 | INFO | labels | Fitted score scale=0.193799 (std_mult=2.00, std=0.096900)
# 2025-12-15 16:52:05,470 | INFO | labels | Fitted score scale=0.192945 (std_mult=2.00, std=0.096473)
# 2025-12-15 16:52:52,919 | INFO | labels | Fitted score scale=0.190634 (std_mult=2.00, std=0.095317)
# 2025-12-15 16:53:52,865 | INFO | labels | Fitted score scale=0.194869 (std_mult=2.00, std=0.097435)
# 2025-12-15 16:54:56,961 | INFO | data | Loading sheet=Dollar Index from C:\Users\fayca\Downloads\hackathon_gold_project\hackathon_gold_project\dataset_train.xlsx
# 2025-12-15 16:55:01,562 | INFO | data | Loaded 12271 rows, columns=['Date', 'Open', 'High', 'Low', 'Close', 'smavg_50', 'smavg_100', 'smavg_240']
# 2025-12-15 16:55:01,566 | INFO | features | Building features...
# 2025-12-15 16:55:01,646 | INFO | features | Features built. Total columns=34
# 2025-12-15 16:55:01,689 | INFO | labels | Fitted score scale=0.041297 (std_mult=2.00, std=0.020648)
# 2025-12-15 16:55:15,339 | INFO | labels | Fitted score scale=0.051192 (std_mult=2.00, std=0.025596)
# 2025-12-15 16:55:41,267 | INFO | labels | Fitted score scale=0.051868 (std_mult=2.00, std=0.025934)
# 2025-12-15 16:56:25,483 | INFO | labels | Fitted score scale=0.049715 (std_mult=2.00, std=0.024858)
# 2025-12-15 16:57:22,838 | INFO | labels | Fitted score scale=0.050064 (std_mult=2.00, std=0.025032)
# 2025-12-15 16:58:24,727 | INFO | data | Loading sheet=EURUSD from C:\Users\fayca\Downloads\hackathon_gold_project\hackathon_gold_project\dataset_train.xlsx
# 2025-12-15 16:58:26,005 | INFO | data | Loaded 11288 rows, columns=['Date', 'Open', 'High', 'Low', 'Close', 'smavg_50', 'smavg_100', 'smavg_240']
# 2025-12-15 16:58:26,007 | INFO | features | Building features...
# 2025-12-15 16:58:26,045 | INFO | features | Features built. Total columns=34
# 2025-12-15 16:58:26,077 | INFO | labels | Fitted score scale=0.052527 (std_mult=2.00, std=0.026263)
# 2025-12-15 16:58:33,764 | INFO | labels | Fitted score scale=0.060090 (std_mult=2.00, std=0.030045)
# 2025-12-15 16:58:51,217 | INFO | labels | Fitted score scale=0.059816 (std_mult=2.00, std=0.029908)
# 2025-12-15 16:59:16,067 | INFO | labels | Fitted score scale=0.058969 (std_mult=2.00, std=0.029484)
# 2025-12-15 16:59:49,108 | INFO | labels | Fitted score scale=0.059790 (std_mult=2.00, std=0.029895)
#           asset          model        ic   dir_acc       mse
# 0    MSCI world          ridge  0.058053  0.430693  0.685453
# 1    MSCI world  random_forest  0.008372  0.394554  0.946715
# 2    MSCI world           gbrt -0.075678  0.373762  1.505200
# 3    MSCI world          ridge -0.053449  0.568317  0.200035
# 4    MSCI world  random_forest  0.164298  0.477723  0.805504
# ..          ...            ...       ...       ...       ...
# 130      EURUSD  random_forest  0.029951  0.498368  0.288372
# 131      EURUSD           gbrt  0.088569  0.494015  0.287685
# 132      EURUSD          ridge -0.005709  0.500000  0.129678
# 133      EURUSD  random_forest  0.065297  0.497280  0.140354
# 134      EURUSD           gbrt  0.148535  0.518498  0.131179
#
# [135 rows x 5 columns]

# %%
results_all
# Out:
#           asset          model        ic   dir_acc       mse
# 0    MSCI world          ridge  0.058053  0.430693  0.685453
# 1    MSCI world  random_forest  0.008372  0.394554  0.946715
# 2    MSCI world           gbrt -0.075678  0.373762  1.505200
# 3    MSCI world          ridge -0.053449  0.568317  0.200035
# 4    MSCI world  random_forest  0.164298  0.477723  0.805504
# ..          ...            ...       ...       ...       ...
# 130      EURUSD  random_forest  0.029951  0.498368  0.288372
# 131      EURUSD           gbrt  0.088569  0.494015  0.287685
# 132      EURUSD          ridge -0.005709  0.500000  0.129678
# 133      EURUSD  random_forest  0.065297  0.497280  0.140354
# 134      EURUSD           gbrt  0.148535  0.518498  0.131179
#
# [135 rows x 5 columns]

# %%
summary = (
    results_all
    .groupby(["asset","model"])
    .mean()
    .reset_index()
    .sort_values(["asset","ic"], ascending=[True, False])
)

summary
# Out:
#             asset          model        ic   dir_acc       mse
# 0          CAC 40           gbrt  0.104343  0.540435  0.367380
# 1          CAC 40  random_forest  0.054719  0.524883  0.410935
# 2          CAC 40          ridge  0.013629  0.471073  0.705627
# 4             Dax  random_forest  0.030571  0.478231  0.442123
# 3             Dax           gbrt  0.021556  0.468191  0.522334
# 5             Dax          ridge -0.010995  0.465308  0.480299
# 7    Dollar Index  random_forest  0.106363  0.500950  0.313029
# 6    Dollar Index           gbrt  0.093039  0.503948  0.365078
# 8    Dollar Index          ridge  0.067493  0.506947  0.267195
# 9          EURUSD           gbrt  0.088047  0.510120  0.306273
# 10         EURUSD  random_forest  0.073521  0.519260  0.267576
# 11         EURUSD          ridge  0.006659  0.494015  0.250469
# 14  Euro stoxx 50          ridge  0.057355  0.489790  0.831916
# 12  Euro stoxx 50           gbrt  0.041115  0.495796  0.537068
# 13  Euro stoxx 50  random_forest  0.036334  0.494595  0.532854
# 17           Gold          ridge  0.082537  0.481798  0.210531
# 15           Gold           gbrt  0.055438  0.476706  0.221100
# 16           Gold  random_forest  0.015276  0.441062  0.205150
# 18     MSCI world           gbrt  0.088124  0.461980  0.620867
# 19     MSCI world  random_forest  0.076511  0.460693  0.538276
# 20     MSCI world          ridge  0.039898  0.515842  0.313962
# 23        Pétrole          ridge  0.141864  0.518915  0.307673
# 21        Pétrole           gbrt  0.118138  0.514186  0.397944
# 22        Pétrole  random_forest  0.101556  0.510431  0.311343
# 24  S&P 500 index           gbrt  0.130109  0.443849  0.434092
# 26  S&P 500 index          ridge  0.107859  0.456548  0.409479
# 25  S&P 500 index  random_forest  0.098040  0.481548  0.250164

# %%
out_path = ROOT / "outputs" / "results_all_assets_models.csv"
summary.to_csv(out_path, index=False)
print("Exported:", out_path)
# Out:
# Exported: C:\Users\fayca\Downloads\hackathon_gold_project\hackathon_gold_project\outputs\results_all_assets_models.csv
